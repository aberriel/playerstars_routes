# %%
import boto3

# %%
ev = boto3.client('events')

# %%
rules=ev.list_rules()

# %%
rules
# Out:
# {'Rules': [{'Name': 'duel-finish-02c8031e-2215-4835-ae12-213076d41eb4',
#    'Arn': 'arn:aws:events:us-east-1:230639242520:rule/duel-finish-02c8031e-2215-4835-ae12-213076d41eb4',
#    'State': 'ENABLED',
#    'ScheduleExpression': 'cron(16 6 18 8 ? 2020)',
#    'EventBusName': 'default'},
#   {'Name': 'duel-finish-0b190510-f192-4678-8f74-4cc6f6bfcb16',
#    'Arn': 'arn:aws:events:us-east-1:230639242520:rule/duel-finish-0b190510-f192-4678-8f74-4cc6f6bfcb16',
#    'State': 'ENABLED',
#    'ScheduleExpression': 'cron(47 1 18 8 ? 2020)',
#    'EventBusName': 'default'},
#   {'Name': 'duel-finish-10ca2e58-161d-47a8-add9-9bc486694465',
#    'Arn': 'arn:aws:events:us-east-1:230639242520:rule/duel-finish-10ca2e58-161d-47a8-add9-9bc486694465',
#    'State': 'ENABLED',
#    'ScheduleExpression': 'cron(24 2 18 8 ? 2020)',
#    'EventBusName': 'default'},
#   {'Name': 'duel-finish-169f6ac4-e642-4c54-b950-2ab6f55924c4',
# ...

# %%
rule = ev.describe_rule(Name='testando-e305adc7-e718-49d2-9ad8-aed551e41c77')

# %%
rule['Arn']
# Out:
# 'arn:aws:events:us-east-1:230639242520:rule/testando-e305adc7-e718-49d2-9ad8-aed551e41c77'
